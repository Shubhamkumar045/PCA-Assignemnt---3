# %%
Q1. What are Eigenvalues and Eigenvectors? How are they related to the Eigen-Decomposition approach?
Explain with an example.
Answer--Eigenvalues and eigenvectors are concepts from linear algebra that play a crucial 
role in various mathematical and computational applications, including eigen-decomposition.

Eigenvalues:

Eigenvalues are scalar values that represent the scaling factor by which an eigenvector 
is stretched or compressed when operated upon by a linear transformation (such as a matrix). 
For a square matrix 
�
A, eigenvalues are denoted by 
�
λ and satisfy the equation:

�
�
=
�
�
Av=λv

where 
�
v is the eigenvector corresponding to eigenvalue 
�
λ.

Eigenvectors:

Eigenvectors are non-zero vectors that remain in the same direction after being 
transformed by a linear transformation (such as a matrix). They are represented by 
�
v and satisfy the equation mentioned above.

Eigen-Decomposition:

Eigen-decomposition is a process of decomposing a square matrix 
�
A into the product of its eigenvectors and eigenvalues. Mathematically, it can be expressed as:
    
Q2. What is eigen decomposition and what is its significance in linear algebra?
Answer--
Eigen-decomposition, also known as eigenvalue decomposition, is a fundamental concept in linear 
algebra that involves decomposing a square matrix into its eigenvectors and eigenvalues.
Mathematically, eigen-decomposition can be represented as follows:

Given a square matrix 
�
A, if there exists a scalar 
�
λ and a non-zero vector 
�
v such that the following equation holds:

�
�
=
�
�
Av=λv

Then 
�
λ is called the eigenvalue corresponding to eigenvector 
�
v of matrix 
�
A.

Eigen-decomposition expresses a square matrix 
�
A as a product of three matrices:
    
Q3. What are the conditions that must be satisfied for a square matrix to be diagonalizable using the
Eigen-Decomposition approach? Provide a brief proof to support your answer.
Answer--For a square matrix to be diagonalizable using the Eigen-Decomposition approach, 
it must satisfy certain conditions. These conditions are as follows:

Matrix Size: The matrix must be square, meaning it has the same number of rows and columns.

Linear Independence of Eigenvectors: The matrix must have a sufficient number of linearly 
independent eigenvectors to span the entire space. In other words, the geometric multiplicity 
of each eigenvalue must equal its algebraic multiplicity.

Completeness of Eigenvectors: The set of eigenvectors must form a complete basis for the vector space.

Q4. What is the significance of the spectral theorem in the context of the Eigen-Decomposition approach?
How is it related to the diagonalizability of a matrix? Explain with an example.
Answer--The spectral theorem is a fundamental result in linear algebra that provides insights 
into the diagonalizability of matrices and the properties of their eigenvalues and eigenvectors. 
In the context of the Eigen-Decomposition approach, the spectral theorem is significant as it
establishes conditions under which a matrix can be diagonalized. Here's how the spectral
theorem is related to the diagonalizability of a matrix:

Spectral Theorem:

The spectral theorem states that for a symmetric matrix 
�
A, there exists an orthogonal matrix 
�
Q and a diagonal matrix 
Λ
Λ such that:
